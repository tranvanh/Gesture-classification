# %%
import pandas as pd
import numpy as np
import os
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Dropout, LSTM, BatchNormalization, Bidirectional
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler, StandardScaler
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# dir_path = './' #local
dir_path = './drive/MyDrive/BAKA/' #colab

# %%
#uncomment in colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
files = os.listdir(dir_path + 'Merged')
files
# Out:
# ['gestures_train.csv', 'gestures_test.csv']

# %%
df_train = pd.read_csv(dir_path + 'Merged/gestures_train.csv')
df_test = pd.read_csv(dir_path + 'Merged/gestures_test.csv')
df_train
# Out:
#         label          a1          a2  ...        z2        z3        z4
# 0           1  171.917694  132.738831  ...  0.000000  0.000000  0.000000
# 1           1  172.026489  132.672134  ... -0.019450  0.028371  0.025351
# 2           1  172.049591  132.658401  ...  0.010556  0.006170  0.006201
# 3           1  172.071579  132.642776  ...  0.013555  0.006168  0.004779
# 4           1  172.092804  132.627594  ...  0.009327  0.003395  0.003071
# ...       ...         ...         ...  ...       ...       ...       ...
# 161795     30  155.428940  174.586319  ... -0.038231 -0.073334 -0.167938
# 161796     30  155.546890  175.031281  ... -0.335571 -0.306252 -0.319984
# 161797     30  155.883240  175.916321  ... -0.086823 -0.160332 -0.248985
# 161798     30  156.244843  176.664246  ... -2.387756 -2.609138 -2.599831
# 161799     30  156.513138  177.219223  ...  0.123741  0.066338 -0.007812
#
# [161800 rows x 33 columns]

# %%
# x = df_train.values #returns a numpy array
# min_max_scaler = MinMaxScaler()
# x_scaled = min_max_scaler.fit_transform(x)
# df_train = pd.DataFrame(x_scaled)

# x = df_test.values #returns a numpy array
# min_max_scaler = MinMaxScaler()
# x_scaled = min_max_scaler.fit_transform(x)
# df_test = pd.DataFrame(x_scaled)

# %%
def calculation(df_rows):
    res = {'omega0': [],
           'omega1': [],
           'omega2': [],
           'omega3': [],
           'omega4': [],
           'beta0': [],
           'beta1': [],
           'beta2': [],
           'beta3': [],
           'beta4': [],
           'u0':[],
           'u1':[],
           'u2':[],
           'u3':[],
           'u4':[],
           'u5':[],
           'v0':[],
           'v1':[],
           'v2':[],
           'v3':[],
           'v4':[],
           'v5':[],
           'z0':[],
           'z1':[],
           'z2':[],
           'z3':[],
           'z4':[],
           'z5':[],
           'gamma3': [],
           'gamma2': [],
           'gamma1': []
          }
    for index, row in df_rows.iterrows():
        #intra-finger angles
        res['gamma3'].append(row['ab'])
        res['gamma2'].append(row['bc'])
        res['gamma1'].append(row['cd'])
        
        #finger tip coordinates
        res['u0'].append(row['x0'])
        res['u1'].append(row['x1'])
        res['u2'].append(row['x2'])
        res['u3'].append(row['x3'])
        res['u4'].append(row['x4'])
        
        res['v0'].append(row['y0'])
        res['v1'].append(row['y1'])
        res['v2'].append(row['y2'])
        res['v3'].append(row['y3'])
        res['v4'].append(row['y4'])
        
        res['z0'].append(row['z0'])
        res['z1'].append(row['z1'])
        res['z2'].append(row['z2'])
        res['z3'].append(row['z3'])
        res['z4'].append(row['z4'])
        
        #palm coordinates
        res['u5'].append(row['px'])
        res['v5'].append(row['py'])
        res['z5'].append(row['pz'])
        
        #joint angles omega
        res['omega0'].append(row['e1'])
        res['omega1'].append(row['d1'])
        res['omega2'].append(row['c1'])
        res['omega3'].append(row['b1'])
        res['omega4'].append(row['a1'])
        
        #joint angles beta
        res['beta0'].append(row['e2'])
        res['beta1'].append(row['d2'])
        res['beta2'].append(row['c2'])
        res['beta3'].append(row['b2'])
        res['beta4'].append(row['a2'])
#     x = pd.DataFrame(res).values #returns a numpy array
#     min_max_scaler = MinMaxScaler()
#     x_scaled = min_max_scaler.fit_transform(x)
#     res = pd.DataFrame(x_scaled)
    res = pd.DataFrame(res)
#     display(res)
    return res.to_numpy()

# %%
def scale_data(data, min_max_scaler):
    for i in range(len(data)):
        data[i] = min_max_scaler.transform(data[i])
    return data

def map_features(df):
    output_df = []
    output_label = []

    for i in range(200,len(df)+1,200):
        if i == 200:
            output_df.append(np.copy(calculation(df[:i])))
            output_label.append(df[:i]['label'][i-1]-1)
        else:
            output_df.append(np.copy(calculation(df[(i-200):i])))
            output_label.append(df[(i-200):i]['label'][i-1]-1)
    return np.array(output_df), np.array(output_label)

# %%
min_max_scaler = MinMaxScaler(feature_range=(0,1))
x_train, y_train = map_features(df_train)

num_instances, num_time_steps, num_features = x_train.shape
x_train = np.reshape(x_train, newshape=(-1, num_features))
x_train = min_max_scaler.fit_transform(x_train)
x_train = np.reshape(x_train, newshape=(num_instances, num_time_steps, num_features))

x_train, y_train = shuffle(x_train, y_train, random_state=0)

x_test, y_test = map_features(df_test)
num_instances, num_time_steps, num_features = x_test.shape
x_test = np.reshape(x_test, newshape=(-1, num_features))
x_test = min_max_scaler.transform(x_test)
x_test = np.reshape(x_test, newshape=(num_instances, num_time_steps, num_features))

x_test, y_test = shuffle(x_test, y_test, random_state=0)

# %%
# x_train = np.delete(x_train, [0,1,2,3,4,5,6,7,8], 0)
# y_train = np.delete(y_train, [0,1,2,3,4,5,6,7,8], 0)
print("x_train.shape: ", x_train.shape)
print("y_train.shiape: ", y_train.shape)
print("x_test.shape: ", x_test.shape)
print("y_test.shape: ", y_test.shape)
# print(y_train)
# print("\n")
# print(y_test)

# print(x_train)
y_train = y_train.astype('int')

# print(y_train)
# Out:
# x_train.shape:  (809, 200, 31)
# y_train.shiape:  (809,)
# x_test.shape:  (389, 200, 31)
# y_test.shape:  (389,)

# %%
print(y_test[0])
# Out:
# 4

# %%
model_1 = Sequential()
model_1.add(Bidirectional(LSTM(units=200 ,dtype='float64'),input_shape=x_train.shape[1:],dtype='float64'))
model_1.add(BatchNormalization())
model_1.add(Dropout(0.2))

# model.add(Dense(30, activation='softmax'))

model_1.add(Dense(30, activation='softmax',dtype='float64'))
model_1.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_40 (Bidirectio (None, 400)               371200
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 400)               1600
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 30)                12030
# =================================================================
# Total params: 384,830
# Trainable params: 384,030
# Non-trainable params: 800
# _________________________________________________________________

# %%
model_2 = Sequential()
model_2.add(Bidirectional(LSTM(units=200, return_sequences=True ,dtype='float64'),input_shape=x_train.shape[1:],dtype='float64'))
model_2.add(BatchNormalization())
model_2.add(Dropout(0.2))

model_2.add(Bidirectional(LSTM(units=200 ,dtype='float64') ,dtype='float64'))
model_2.add(BatchNormalization())
model_2.add(Dropout(0.2))


# model.add(Dense(30, activation='softmax'))

model_2.add(Dense(30, activation='softmax',dtype='float64'))
model_2.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_41 (Bidirectio (None, 200, 400)          371200
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 200, 400)          1600
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 200, 400)          0
# _________________________________________________________________
# bidirectional_42 (Bidirectio (None, 400)               961600
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 400)               1600
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 30)                12030
# =================================================================
# Total params: 1,348,030
# Trainable params: 1,346,430
# Non-trainable params: 1,600
# _________________________________________________________________

# %%
model_3 = Sequential()
model_3.add(Bidirectional(LSTM(units=200, return_sequences=True ,dtype='float64'),input_shape=x_train.shape[1:],dtype='float64'))
model_3.add(BatchNormalization())
model_3.add(Dropout(0.2))

model_3.add(Bidirectional(LSTM(units=200, return_sequences=True ,dtype='float64') ,dtype='float64'))
model_3.add(BatchNormalization())
model_3.add(Dropout(0.2))

model_3.add(Bidirectional(LSTM(units=200 ,dtype='float64') ,dtype='float64'))
model_3.add(BatchNormalization())
model_3.add(Dropout(0.2))


# model.add(Dense(30, activation='softmax'))

model_3.add(Dense(30, activation='softmax',dtype='float64'))
model_3.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_43 (Bidirectio (None, 200, 400)          371200
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 200, 400)          1600
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 200, 400)          0
# _________________________________________________________________
# bidirectional_44 (Bidirectio (None, 200, 400)          961600
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 200, 400)          1600
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 200, 400)          0
# _________________________________________________________________
# bidirectional_45 (Bidirectio (None, 400)               961600
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 400)               1600
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 30)                12030
# =================================================================
# Total params: 2,311,230
# Trainable params: 2,308,830
# Non-trainable params: 2,400
# _________________________________________________________________

# %%
model_4 = Sequential()
model_4.add(Bidirectional(LSTM(units=200, return_sequences=True ,dtype='float64'),input_shape=x_train.shape[1:],dtype='float64'))
model_4.add(BatchNormalization())
model_4.add(Dropout(0.2))

model_4.add(Bidirectional(LSTM(units=200, return_sequences=True ,dtype='float64') ,dtype='float64'))
model_4.add(BatchNormalization())
model_4.add(Dropout(0.2))

model_4.add(Bidirectional(LSTM(units=200, return_sequences=True ,dtype='float64') ,dtype='float64'))
model_4.add(BatchNormalization())
model_4.add(Dropout(0.2))

model_4.add(Bidirectional(LSTM(units=200 ,dtype='float64') ,dtype='float64'))
model_4.add(BatchNormalization())
model_4.add(Dropout(0.2))


# model.add(Dense(30, activation='softmax'))

model_4.add(Dense(30, activation='softmax',dtype='float64'))
model_4.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_46 (Bidirectio (None, 200, 400)          371200
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 200, 400)          1600
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 200, 400)          0
# _________________________________________________________________
# bidirectional_47 (Bidirectio (None, 200, 400)          961600
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 200, 400)          1600
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 200, 400)          0
# _________________________________________________________________
# bidirectional_48 (Bidirectio (None, 200, 400)          961600
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 200, 400)          1600
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 200, 400)          0
# _________________________________________________________________
# bidirectional_49 (Bidirectio (None, 400)               961600
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 400)               1600
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 400)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 30)                12030
# =================================================================
# Total params: 3,274,430
# Trainable params: 3,271,230
# Non-trainable params: 3,200
# _________________________________________________________________

# %%
models = [model_1, model_2, model_3, model_4]

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=1e-5)

gestures = []

for m in models:
  m.compile(
      loss='sparse_categorical_crossentropy',
      optimizer=opt,
      metrics=['accuracy'],
  )

  gestures.append(m.fit(x = x_train,
            y = y_train,
            epochs=100,
            validation_split=0.1, #split 10% of the trainning set for the validation set,
            batch_size=24,
            shuffle=True
          ))
# Out:
# Epoch 1/60
# 31/31 [==============================] - 39s 205ms/step - loss: 3.1214 - accuracy: 0.1772 - val_loss: 3.2803 - val_accuracy: 0.1358
# Epoch 2/60
# 31/31 [==============================] - 6s 183ms/step - loss: 2.0054 - accuracy: 0.4505 - val_loss: 3.1532 - val_accuracy: 0.1605
# Epoch 3/60
# 31/31 [==============================] - 6s 183ms/step - loss: 1.5542 - accuracy: 0.5604 - val_loss: 3.0258 - val_accuracy: 0.2716
# Epoch 4/60
# 31/31 [==============================] - 6s 183ms/step - loss: 1.2993 - accuracy: 0.6236 - val_loss: 2.8791 - val_accuracy: 0.2469
# Epoch 5/60
# 31/31 [==============================] - 6s 184ms/step - loss: 1.1079 - accuracy: 0.6854 - val_loss: 2.6988 - val_accuracy: 0.3457
# Epoch 6/60
# 31/31 [==============================] - 6s 185ms/step - loss: 0.9894 - accuracy: 0.7486 - val_loss: 2.4628 - val_accuracy: 0.3333
# Epoch 7/60
# 31/31 [==============================] - 6s 185ms/step - loss: 0.8883 - accuracy: 0.7843 - val_loss: 2.1758 - val_accuracy: 0.5309
# Epoch 8/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.8203 - accuracy: 0.8063 - val_loss: 1.9964 - val_accuracy: 0.7037
# Epoch 9/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.7854 - accuracy: 0.8022 - val_loss: 1.7608 - val_accuracy: 0.6543
# Epoch 10/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.7344 - accuracy: 0.8338 - val_loss: 1.6005 - val_accuracy: 0.6914
# Epoch 11/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.7159 - accuracy: 0.8365 - val_loss: 1.2354 - val_accuracy: 0.7160
# Epoch 12/60
# 31/31 [==============================] - 6s 185ms/step - loss: 0.6723 - accuracy: 0.8407 - val_loss: 1.0577 - val_accuracy: 0.8025
# Epoch 13/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.6140 - accuracy: 0.8530 - val_loss: 0.9116 - val_accuracy: 0.7778
# Epoch 14/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.6418 - accuracy: 0.8420 - val_loss: 0.8600 - val_accuracy: 0.7654
# Epoch 15/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.5977 - accuracy: 0.8599 - val_loss: 0.6486 - val_accuracy: 0.8519
# Epoch 16/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.5962 - accuracy: 0.8681 - val_loss: 0.6899 - val_accuracy: 0.8642
# Epoch 17/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0.5603 - accuracy: 0.8764 - val_loss: 0.6173 - val_accuracy: 0.8642
# Epoch 18/60
# 31/31 [==============================] - 6s 184ms/step - loss: 0
60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3985 - accuracy: 0.8860 - val_loss: 0.5338 - val_accuracy: 0.9136
# Epoch 15/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3632 - accuracy: 0.8956 - val_loss: 0.7370 - val_accuracy: 0.8395
# Epoch 16/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3766 - accuracy: 0.8929 - val_loss: 0.6693 - val_accuracy: 0.8395
# Epoch 17/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3836 - accuracy: 0.8723 - val_loss: 0.6265 - val_accuracy: 0.8395
# Epoch 18/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3556 - accuracy: 0.8901 - val_loss: 0.6784 - val_accuracy: 0.8148
# Epoch 19/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3105 - accuracy: 0.8929 - val_loss: 0.6433 - val_accuracy: 0.8148
# Epoch 20/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3568 - accuracy: 0.8956 - val_loss: 0.6107 - val_accuracy: 0.8765
# Epoch 21/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3336 - accuracy: 0.8915 - val_loss: 0.5790 - val_accuracy: 0.8889
# Epoch 22/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2835 - accuracy: 0.9066 - val_loss: 0.8138 - val_accuracy: 0.8395
# Epoch 23/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2759 - accuracy: 0.9107 - val_loss: 0.6179 - val_accuracy: 0.8765
# Epoch 24/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2718 - accuracy: 0.9052 - val_loss: 0.6064 - val_accuracy: 0.8889
# Epoch 25/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2623 - accuracy: 0.9176 - val_loss: 0.6030 - val_accuracy: 0.8889
# Epoch 26/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2649 - accuracy: 0.9107 - val_loss: 0.6208 - val_accuracy: 0.8765
# Epoch 27/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.3204 - accuracy: 0.9148 - val_loss: 0.5282 - val_accuracy: 0.8765
# Epoch 28/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2613 - accuracy: 0.9107 - val_loss: 0.7174 - val_accuracy: 0.8519
# Epoch 29/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2167 - accuracy: 0.9286 - val_loss: 0.5735 - val_accuracy: 0.8765
# Epoch 30/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2938 - accuracy: 0.9107 - val_loss: 0.5985 - val_accuracy: 0.8765
# Epoch 31/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2485 - accuracy: 0.9190 - val_loss: 0.5758 - val_accuracy: 0.8765
# Epoch 32/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2330 - accuracy: 0.9245 - val_loss: 0.5839 - val_accuracy: 0.8765
# Epoch 33/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1921 - accuracy: 0.9396 - val_loss: 0.6284 - val_accuracy: 0.8395
# Epoch 34/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2062 - accuracy: 0.9382 - val_loss: 0.5671 - val_accuracy: 0.8889
# Epoch 35/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1857 - accuracy: 0.9396 - val_loss: 0.6070 - val_accuracy: 0.9012
# Epoch 36/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2623 - accuracy: 0.9354 - val_loss: 0.7110 - val_accuracy: 0.8395
# Epoch 37/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2665 - accuracy: 0.9203 - val_loss: 0.7550 - val_accuracy: 0.8519
# Epoch 38/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2622 - accuracy: 0.9231 - val_loss: 0.6549 - val_accuracy: 0.8395
# Epoch 39/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2510 - accuracy: 0.9217 - val_loss: 0.6114 - val_accuracy: 0.8642
# Epoch 40/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2305 - accuracy: 0.9299 - val_loss: 0.5194 - val_accuracy: 0.9012
# Epoch 41/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2398 - accuracy: 0.9231 - val_loss: 0.5665 - val_accuracy: 0.8889
# Epoch 42/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2391 - accuracy: 0.9368 - val_loss: 0.6824 - val_accuracy: 0.8642
# Epoch 43/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1864 - accuracy: 0.9437 - val_loss: 0.6830 - val_accuracy: 0.8395
# Epoch 44/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1937 - accuracy: 0.9382 - val_loss: 0.6007 - val_accuracy: 0.8765
# Epoch 45/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1974 - accuracy: 0.9313 - val_loss: 0.6172 - val_accuracy: 0.8519
# Epoch 46/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1804 - accuracy: 0.9437 - val_loss: 0.5804 - val_accuracy: 0.8642
# Epoch 47/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2076 - accuracy: 0.9341 - val_loss: 0.5730 - val_accuracy: 0.8519
# Epoch 48/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2062 - accuracy: 0.9341 - val_loss: 0.7154 - val_accuracy: 0.8272
# Epoch 49/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2031 - accuracy: 0.9451 - val_loss: 0.7405 - val_accuracy: 0.8025
# Epoch 50/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1696 - accuracy: 0.9505 - val_loss: 0.5624 - val_accuracy: 0.8765
# Epoch 51/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1927 - accuracy: 0.9451 - val_loss: 0.5621 - val_accuracy: 0.8765
# Epoch 52/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1804 - accuracy: 0.9519 - val_loss: 0.6764 - val_accuracy: 0.8395
# Epoch 53/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1840 - accuracy: 0.9409 - val_loss: 0.5764 - val_accuracy: 0.8642
# Epoch 54/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1595 - accuracy: 0.9505 - val_loss: 0.9365 - val_accuracy: 0.8272
# Epoch 55/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1746 - accuracy: 0.9451 - val_loss: 0.6185 - val_accuracy: 0.8765
# Epoch 56/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1291 - accuracy: 0.9629 - val_loss: 0.5954 - val_accuracy: 0.8765
# Epoch 57/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.2045 - accuracy: 0.9368 - val_loss: 0.7639 - val_accuracy: 0.8519
# Epoch 58/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1740 - accuracy: 0.9409 - val_loss: 0.8653 - val_accuracy: 0.8148
# Epoch 59/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1620 - accuracy: 0.9519 - val_loss: 0.6926 - val_accuracy: 0.8765
# Epoch 60/60
# 31/31 [==============================] - 36s 1s/step - loss: 0.1656 - accuracy: 0.9505 - val_loss: 0.5855 - val_accuracy: 0.8889

# %%
# model.save(dir_path + 'Models/gestures.h5')

# %%
layer = 1
for m in models:

  print(layer," = Evaluate on test data")
  layer += 1
  results = m.evaluate(x_test, y_test, batch_size=24)
  print("test loss, test acc:", results)
  # model.save(dir_path + 'Models/gestures', save_format='tf')
# Out:
# 1  = Evaluate on test data
# 17/17 [==============================] - 1s 67ms/step - loss: 0.7963 - accuracy: 0.8123
# test loss, test acc: [0.7963303327560425, 0.8123393058776855]
# 2  = Evaluate on test data
# 17/17 [==============================] - 3s 192ms/step - loss: 0.7339 - accuracy: 0.8355
# test loss, test acc: [0.7339449524879456, 0.8354755640029907]
# 3  = Evaluate on test data
# 17/17 [==============================] - 6s 324ms/step - loss: 0.7175 - accuracy: 0.8458
# test loss, test acc: [0.7174612879753113, 0.8457583785057068]
# 4  = Evaluate on test data
# 17/17 [==============================] - 8s 449ms/step - loss: 0.7762 - accuracy: 0.8329
# test loss, test acc: [0.7762163877487183, 0.8329048752784729]

# %%
# new_model = load_model(dir_path + 'Models/gestures.h5')
# print("Evaluate on test data")
# results = new_model.evaluate(x_test, y_test, batch_size=80)
# print("test loss, test acc:", results)
